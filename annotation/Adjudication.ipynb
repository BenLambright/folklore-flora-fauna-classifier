# %%
import os

# get the current working directory
current_working_directory = os.getcwd()

# print output to the console
print(current_working_directory)
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/Shareddrives/Folklore/'Folklore and Fauna Project'/data/Annotated
print("=" * 50)
# !ls /content/drive/Shareddrives/Folklore/'Folklore and Fauna Project'/data/Annotated/'Folktales v2 Emily'
print("=" * 50)
# !ls /content/drive/Shareddrives/Folklore/'Folklore and Fauna Project'/data/Annotated/'Folktales v2 Kasey'
print("=" * 50)
# !ls /content/drive/Shareddrives/Folklore/'Folklore and Fauna Project'/data/Annotated/'Folktales v2 Keer'
print("=" * 50)
# !ls /content/drive/Shareddrives/Folklore/'Folklore and Fauna Project'/data/Annotated/'Folktales v2 Joyce'
# Out:
# 'Folktales v2 Emily'  'Folktales v2 Joyce.tar.gz'  'Folktales v2 Keer'
# 'Folktales v2 Joyce'  'Folktales v2 Kasey'	   'Folktales v2_Keer.tar.gz'
# ==================================================
# annotation.conf  Cherokee  Filipino  Japanese  Maori  Seneca
# ==================================================
# annotation.conf  annotation.confZone.Identifier  Cherokee  Filipino  Japanese	Maori  Seneca
# ==================================================
# annotation.conf  Cherokee  Filipino  Japanese  Maori  Seneca
# ==================================================
# annotation.conf  Cherokee  Filipino  Japanese  Maori  Seneca

# %%
def dict_of_annotations(path):
  '''
  path: filepath for the .ann file
  return: a dictionary for the annotation file that includes all of the flora and fauna in the file, and a tuple of their motifs
  return: {flora/fauna: tuple(protag/antag, good/evil)}
  '''
  file_dict = {}  # dict to return
  tag_dict = {}  # dict mapping each tag to its flora/fauna
  motif_tuple = ()  # tuple of motifs for each flora/fauna
  prev_attributed_tag = None # saving the tag aka flora/fauna that has the attribute in case the next attribute doesn't match

  # open the file
  with open(path, 'r') as file:
    for line in file:

      if line[0] == 'T':
        # add all the flora/fauna to the dictionary
        file_dict[line.split()[1]] = None
        tag_dict[line.split()[0]] = line.split()[1]

      elif line[0] == 'A':
        # map the motifs as tuples (protag/antag, good/evil) to their animal
        curr_attributed_tag = line.split()[2]
        # edgecase: if the annotator only added one of the two motifs for a tag
        if prev_attributed_tag != curr_attributed_tag and len(motif_tuple) != 0:
          file_dict[tag_dict[prev_attributed_tag]] = motif_tuple
          motif_tuple = ()
        # if the tuple for this flora/fauna is currently empty
        if len(motif_tuple) == 0:
          motif_tuple = (line.split()[-1],)
        # if it just has one, add the good/evil feature, add the tuple to the dict then wipe the tuple
        elif len(motif_tuple) == 1:
          motif_tuple += (line.split()[-1],)
          file_dict[tag_dict[curr_attributed_tag]] = motif_tuple
          motif_tuple = ()
        prev_attributed_tag = curr_attributed_tag

    return file_dict

# %%
import os
import pprint

annotator_pairs = [("Emily", "Kasey"), ("Keer", "Joyce")]
cultures = ["Cherokee", "Filipino", "Maori", "Seneca", "Japanese"]
ann_file_dict = {}

ann_dir = "/content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily"

for root, dirs, files in os.walk(ann_dir):
  print(root)
  for file in files:
    filename = os.path.join(root, file)
# Out:
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori

# %%
import os
import pprint

annotator_pairs = [("Emily", "Kasey"), ("Keer", "Joyce")]
cultures = ["Cherokee", "Filipino", "Maori", "Seneca", "Japanese"]
ann_file_dict = {}

for annotator_pair in annotator_pairs:
    ann_file_dict[annotator_pair] = []
    ann_dir = f"/content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 {annotator_pair[0]}"
    for root, dirs, files in os.walk(ann_dir):
        for file in files:
          if file.endswith(".ann"):
            filename = os.path.join(root, file)
            ann_file_dict[annotator_pair].append((filename, filename.replace(annotator_pair[0], annotator_pair[1])))

def fix_annotation(annotation):
  roles = ["Protagonist", "Default", "Antagonist"]
  alignments = ["Good", "Neutral", "Evil"]

  if annotation[0] in roles:
    return (annotation[0], "Neutral")
  if annotation[0] in alignments:
    return ("Default", annotation[0])

#cohen's kappa
def count_agreements(file1, file2, verbose = True):
  if verbose: print(file1)

  role_agreements = 0
  alignment_agreements = 0
  total = 0

  ann_dict1 = dict_of_annotations(file1)
  ann_dict2 = dict_of_annotations(file2)

  for key in set(ann_dict1.keys()) | set(ann_dict2.keys()):

    #ignore mutual missed annotations (both did not)
    if (key not in ann_dict1.keys() or (not ann_dict1[key])) and (key not in ann_dict2.keys() or (not ann_dict2[key])): continue

    #assume missing values if anns did not annotate
    if key not in ann_dict1.keys() or (not ann_dict1[key]): ann_dict1[key] = ('Default', 'Neutral')
    if key not in ann_dict2.keys() or (not ann_dict2[key]): ann_dict2[key] = ('Default', 'Neutral')
    #assume missing values
    if len(ann_dict1[key]) == 1: ann_dict1[key] = fix_annotation(ann_dict1[key])
    if len(ann_dict2[key]) == 1: ann_dict2[key] = fix_annotation(ann_dict2[key])

    #remove unimportant cases
    if ann_dict1[key] == ('Default', 'Neutral') and ann_dict2[key] == ('Default', 'Neutral'): continue

    #values we're working with
    if verbose: print(key, ann_dict1[key], ann_dict2[key])

    role_agreements += 1 if ann_dict1[key][0] == ann_dict2[key][0] else 0
    alignment_agreements += 1 if ann_dict1[key][1] == ann_dict2[key][1] else 0
    total += 1

  if verbose: print(role_agreements, alignment_agreements, total)
  return (role_agreements, alignment_agreements, total)

# note: had to delete a file because Joyce had it but Keer didn't
def view_disagreements(file1, file2):
  ann_dict1 = dict_of_annotations(file1)
  ann_dict2 = dict_of_annotations(file2)

  output = ""
  for key in ann_dict1.keys():
    output += key + ": "
    if key in ann_dict2:
      pprint.pprint([key, ann_dict1[key], ann_dict2[key]])
    else:  # edgecase: annotator adds additional tag + attribute even though they're not supposed to
      pprint.pprint([key, ann_dict1[key],])

  #return output

import numpy as np
for annotator_pair in annotator_pairs:
  print(annotator_pair)
  agreement_triple = np.array([0, 0, 0]) #role_agreements, alignments_agreements, count)
  for file_pair in ann_file_dict[annotator_pair]:
    with open(file_pair[0], "r") as f:
      if "A1" in f.read():
        agreement_triple += np.array(count_agreements(file_pair[0], file_pair[1]))
  #cohen's kappa: (p_o - p_e) / (1 - p_e)
  print("Role, Alignment, Total: ", agreement_triple)
  print("Role kappa: " , (agreement_triple[0]/agreement_triple[2] - 1/3) / (2/3))
  print("Alignment kappa: " , (agreement_triple[1]/agreement_triple[2] - 1/3) / (2/3))
# Out:
# ('Emily', 'Kasey')
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/HowtheTinguianLearnedtoPlant.ann
# Canine ('Default', 'Neutral') ('Default', 'Evil')
# Fish ('Default', 'Neutral') ('Default', 'Good')
# 2 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/Sogsogot.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/The Boy who became a Stone.ann
# Bird ('Antagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/The Carabao and the Shell.ann
# Ungulate ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/The Dogedog.ann
# Crocodilia ('Default', 'Neutral') ('Default', 'Good')
# Insect ('Default', 'Neutral') ('Default', 'Good')
# Crop ('Default', 'Neutral') ('Default', 'Good')
# Ungulate ('Default', 'Neutral') ('Default', 'Good')
# Primate ('Default', 'Neutral') ('Default', 'Good')
# Fowl ('Default', 'Good') ('Default', 'Neutral')
# 6 0 6
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/The Man with the Coconuts.ann
# Fern ('Default', 'Neutral') ('Default', 'Good')
# Ungulate ('Default', 'Neutral') ('Default', 'Good')
# 2 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/TheAlanandtheHunters.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/TheBattleoftheCrabs.ann
# Decapod ('Antagonist', 'Good') ('Neutral', 'Protagonist')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Filipino/TheCreationStory.ann
# Crop ('Antagonist', 'Evil') ('Default', 'Good')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/BearsRaceWithTurtle.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# Bear ('Protagonist', 'Evil') ('Protagonist', 'Neutral')
# Canine ('Default', 'Neutral') ('Default', 'Good')
# Testudine ('Antagonist', 'Good') ('Antagonist', 'Neutral')
# 4 0 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/BoyAndTheRattlesnakeStory.ann
# Snake ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/HowTheDeerGotHisHorns.ann
# Lagomorph ('Antagonist', 'Neutral') ('Antagonist', 'Evil')
# Ungulate ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# 2 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/HowTheHoneyBeeGotTheirStinger.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# Flower ('Protagonist', 'Good') ('Default', 'Good')
# Insect ('Protagonist', 'Good') ('Protagonist', 'Good')
# 2 2 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/HowThePartridgeGotHisWhistle.ann
# Fowl ('Default', 'Evil') ('Antagonist', 'Evil')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/HowTheRabbitStoleTheOttersCoat.ann
# Bear ('Default', 'Neutral') ('Default', 'Good')
# Mustelid ('Antagonist', 'Good') ('Protagonist', 'Neutral')
# Lagomorph ('Protagonist', 'Evil') ('Antagonist', 'Evil')
# 1 1 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/HowTheRedbirdGotHisColor.ann
# Canine ('Protagonist', 'Good') ('Default', 'Neutral')
# Other-Mammal ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/LifeLessonForAllCherokee.ann
# Bear ('Antagonist', 'Evil') ('Default', 'Neutral')
# Raptor ('Protagonist', 'Good') ('Default', 'Good')
# Rodent ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# Bat ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# 2 1 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/OriginOfDiseaseAndMedicine.ann
# Tree ('Default', 'Good') ('Default', 'Good')
# Snake ('Default', 'Neutral') ('Protagonist', 'Neutral')
# Fish ('Default', 'Neutral') ('Protagonist', 'Neutral')
# Ungulate ('Protagonist', 'Good') ('Antagonist', 'Good')
# Insect ('Default', 'Neutral') ('Neutral', 'Default')
# Plant ('Default', 'Good') ('Default', 'Good')
# Bear ('Protagonist', 'Good') ('Antagonist', 'Good')
# Rodent ('Default', 'Neutral') ('Protagonist', 'Neutral')
# Primate ('Antagonist', 'Evil') ('Protagonist', 'Neutral')
# Shrub ('Default', 'Good') ('Default', 'Good')
# 3 8 10
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Cherokee/OriginOfTheBear.ann
# Bear ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/AWarriorCaredForByWolves.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# Canine ('Default', 'Good') ('Protagonist', 'Good')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/AYoungManRescuedByAToad.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/CoonDeceivesCrawfish.ann
# Decapod ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# Other-Mammal ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# 2 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/DogsSaveTheirMaster.ann
# Canine ('Default', 'Good') ('Protagonist', 'Good')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheBoyWhoLivedWithTheBears.ann
# Bear ('Default', 'Good') ('Default', 'Neutral')
# Canine ('Default', 'Neutral') ('Default', 'Evil')
# Rodent ('Default', 'Good') ('Default', 'Good')
# Bird ('Default', 'Neutral') ('Default', 'Evil')
# Coniferous ('Default', 'Neutral') ('Default', 'Good')
# Shrub ('Default', 'Neutral') ('Default', 'Good')
# 6 1 6
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheBoyWhoOvercameAllMagicByLaughter.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheChipmunk_sStripes.ann
# Bear ('Protagonist', 'Evil') ('Antagonist', 'Neutral')
# Rodent ('Antagonist', 'Good') ('Protagonist', 'Neutral')
# 0 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheManWhoExhaledFire-HisDogsAndTheWolves.ann
# Canine ('Antagonist', 'Evil') ('Antagonist', 'Neutral')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheOriginOfTheBuffaloSociety.ann
# Ungulate ('Default', 'Good') ('Default', 'Neutral')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheRabbitSong.ann
# Lagomorph ('Protagonist', 'Neutral') ('Neutral', 'Default')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Seneca/GTB-TheRaccoonAndTheCrabs.ann
# Other-Mammal ('Protagonist', 'Good') ('Default', 'Neutral')
# Decapod ('Antagonist', 'Evil') ('Default', 'Neutral')
# 0 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/HOW AN OLD MAN LOST HIS WEN.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/MOMOTARO, OR THE STORY OF THE SON O.ann
# Bird ('Default', 'Neutral') ('Default', 'Good')
# Fowl ('Protagonist', 'Good') ('Default', 'Good')
# Canine ('Protagonist', 'Good') ('Default', 'Good')
# Primate ('Protagonist', 'Good') ('Default', 'Good')
# 1 3 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/MY LORD BAG OF RICE.ann
# Snake ('Protagonist', 'Good') ('Default', 'Neutral')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE ADVENTURES OF KINTARO, THE GOLD.ann
# Bear ('Default', 'Good') ('Default', 'Good')
# Lagomorph ('Default', 'Good') ('Default', 'Good')
# Ungulate ('Default', 'Good') ('Default', 'Good')
# Primate ('Default', 'Good') ('Default', 'Good')
# 4 4 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE BAMBOO-CUTTER AND THE MOON-CHIL.ann
# Crop ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE FARMER AND THE BADGER.ann
# Mustelid ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# Lagomorph ('Protagonist', 'Good') ('Protagonist', 'Good')
# Crop ('Default', 'Neutral') ('Default', 'Good')
# 3 2 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE GOBLIN OF ADACHIGAHARA.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE HAPPY HUNTER AND THE SKILLFUL F.ann
# Mustelid ('Antagonist', 'Evil') ('Default', 'Neutral')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE JELLY FISH AND THE MONKEY.ann
# Fish ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Primate ('Antagonist', 'Neutral') ('Antagonist', 'Neutral')
# 1 2 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Japanese/THE MIRROR OF MATSUYAMA.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Tamaika and Hanokai.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/The Cuckoo.ann
# Mbb ('Protagonist', 'Good') ('Default', 'Neutral')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Story of the Ruruhi-kerepo.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Shellfish as a Love Messenger.ann
# Bird ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/All Creatures Possess the Faculty o.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Fable of the Aute or Paper Mulberry.ann
# Deciduous ('Default', 'Neutral') ('Protagonist', 'Good')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Fable of the Hawk and the Hokioi.ann
# Bird ('Protagonist', 'Good') ('Default', 'Neutral')
# Raptor ('Antagonist', 'Evil') ('Default', 'Neutral')
# 0 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Fight between Lizards and Dogs.ann
# Canine ('Antagonist', 'Evil') ('Default', 'Neutral')
# Lizard ('Protagonist', 'Evil') ('Default', 'Neutral')
# 0 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Fire Versus Water.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Flying Men.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/How the Pukeko or Swamp Hen Became .ann
# Strigiform ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Bat ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Bird ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# Fowl ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 1 4 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/How the Totara Came to Pop When Bur.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Origin of the Taiaha and of the Kum.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# Crop ('Protagonist', 'Good') ('Default', 'Neutral')
# 1 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Emily/Maori/Seal Caught with Hook and Line.ann
# 0 0 0
# Role, Alignment, Total:  [53 37 93]
# Role kappa:  0.3548387096774195
# Alignment kappa:  0.0967741935483871
# ('Keer', 'Joyce')
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheFirstMonkey.ann
# Crop ('Default', 'Neutral') ('Protagonist', 'Good')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheHawkandtheHen.ann
# Raptor ('Protagonist', 'Neutral') ('Protagonist', 'Good')
# Fowl ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheMonkeyandtheTurtle.ann
# Testudine ('Default', 'Neutral') ('Antagonist', 'Evil')
# Primate ('Protagonist', 'Neutral') ('Protagonist', 'Evil')
# 1 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheSpiderandtheFly.ann
# Insect ('Default', 'Neutral') ('Antagonist', 'Evil')
# Spider ('Protagonist', 'Evil') ('Protagonist', 'Neutral')
# 1 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheStoryofaMonkey.ann
# Primate ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# Canine ('Default', 'Evil') ('Default', 'Evil')
# 2 2 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheStripedBlanket.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheTreewiththeAgateBeads.ann
# Shrub ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheTurtleandtheLizard.ann
# Lizard ('Protagonist', 'Evil') ('Default', 'Neutral')
# Testudine ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# Crop ('Default', 'Neutral') ('Default', 'Good')
# 2 0 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheVirtueoftheCocoanut.ann
# Tree ('Default', 'Neutral') ('Protagonist', 'Neutral')
# Ungulate ('Default', 'Neutral') ('Default', 'Evil')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/TheWhiteSquash.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Filipino/WhyDogsWagtheirTails.ann
# Canine ('Protagonist', 'Evil') ('Protagonist', 'Evil')
# Feline ('Protagonist', 'Neutral') ('Protagonist', 'Good')
# 2 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Cuckoo.ann
# Mbb ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Deceiving of Kapoho.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Great Battle Between the Fish T.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Green Lizard and the Rat.ann
# Rodent ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Kaka and Kakariki.ann
# Bird ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Kokako and the Huia.ann
# Corvid ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Korotangi Myth.ann
# Bird ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Lone Pine of Taka-ahuru.ann
# Tree ('Default', 'Neutral') ('Default', 'Good')
# Coniferous ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Popokorua and the Kihikihi_ the.ann
# Insect ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Sandfly and the Mosquito.ann
# Insect ('Protagonist', 'Neutral') ('Protagonist', 'Evil')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Shark and the Tuatara Lizard.ann
# Lizard ('Protagonist', 'Neutral') ('Antagonist', 'Neutral')
# Chondrichthye ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# Deciduous ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Fish ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 1 4 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Talking Heads of Manga-o-Tane.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Tuatara and the Kumukumu.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/The Woman who Ate her Child_s Heart.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Maori/War Between the Mussel and Cockle T.ann
# Chondrichthye ('Default', 'Neutral') ('Default', 'Evil')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/GTB-TheRaceOfTheTurtleAndTheBeaver.ann
# Testudine ('Protagonist', 'Evil') ('Protagonist', 'Neutral')
# Rodent ('Protagonist', 'Neutral') ('Antagonist', 'Neutral')
# Flora_or_Fauna ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 1 2 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/GTB-TheTurtlesWarParty.ann
# Snake ('Default', 'Neutral') ('Antagonist', 'Neutral')
# Testudine ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/GTB-TheWolfAndTheRaccoonAndHowTheBirdsWerePainted.ann
# Canine ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Bird ('Default', 'Neutral') ('Default', 'Good')
# Other-Mammal ('Antagonist', 'Neutral') ('Default', 'Neutral')
# 1 2 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/GTB-TwentgowaAndTheMischiefMaker.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/HowChipmunksGotTheirStripes.ann
# Bear ('Protagonist', 'Evil') ('Default', 'Neutral')
# Rodent ('Protagonist', 'Neutral') ('Default', 'Neutral')
# Flora_or_Fauna ('Protagonist', 'Evil') ('Default', 'Neutral')
# 0 1 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/TheFoxAndRabbit.ann
# Lagomorph ('Default', 'Neutral') ('Protagonist', 'Good')
# Canine ('Default', 'Neutral') ('Antagonist', 'Evil')
# 0 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/TheFriendshipOfAnOtter.ann
# Mustelid ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/TheGreatSnakeBattle.ann
# Snake ('Default', 'Neutral') ('Antagonist', 'Neutral')
# 0 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/TheHunterWhoBecameAFish.ann
# Bear ('Protagonist', 'Evil') ('Antagonist', 'Neutral')
# Fish ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/ThunderDestroysHornedSnake.ann
# Snake ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Seneca/GTB-TwoFeatherAndTurkeyBrother.ann
# Snake ('Default', 'Good') ('Default', 'Good')
# Spider ('Default', 'Good') ('Default', 'Good')
# Insect ('Default', 'Evil') ('Default', 'Evil')
# Fowl ('Default', 'Neutral') ('Protagonist', 'Neutral')
# Bear ('Default', 'Neutral') ('Default', 'Good')
# Lizard ('Default', 'Evil') ('Default', 'Evil')
# Ciconiidae ('Default', 'Neutral') ('Default', 'Good')
# 6 5 7
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE WHITE HARE AND THE CROCODILES.ann
# Lagomorph ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# Crocodilia ('Protagonist', 'Neutral') ('Antagonist', 'Evil')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE TONGUE-CUT SPARROW.ann
# Snake ('Default', 'Neutral') ('Default', 'Evil')
# Lbb ('Protagonist', 'Good') ('Protagonist', 'Good')
# Bird ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 2 2 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE STORY OF URASHIMA TARO, THE FIS.ann
# Testudine ('Protagonist', 'Good') ('Default', 'Good')
# Insect ('Default', 'Neutral') ('Default', 'Good')
# Deciduous ('Default', 'Neutral') ('Default', 'Good')
# 2 1 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE STORY OF THE OLD MAN WHO MADE W.ann
# Canine ('Protagonist', 'Good') ('Default', 'Good')
# Deciduous ('Default', 'Neutral') ('Default', 'Good')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE STORY OF THE MAN WHO DID NOT WI.ann
# Chondrichthye ('Default', 'Neutral') ('Antagonist', 'Evil')
# Bird ('Protagonist', 'Neutral') ('Default', 'Neutral')
# 0 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE STORY OF PRINCE YAMATO TAKE.ann
# Snake ('Default', 'Neutral') ('Antagonist', 'Evil')
# Flower ('Default', 'Neutral') ('Default', 'Good')
# 1 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE OGRE OF RASHOMON.ann
# 0 0 0
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE QUARREL OF THE MONKEY AND THE C.ann
# Decapod ('Protagonist', 'Good') ('Protagonist', 'Good')
# Deciduous ('Default', 'Neutral') ('Default', 'Good')
# Primate ('Antagonist', 'Evil') ('Antagonist', 'Evil')
# Insect ('Default', 'Neutral') ('Default', 'Good')
# 4 2 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE STONES OF FIVE COLORS AND THE E.ann
# Testudine ('Default', 'Neutral') ('Default', 'Good')
# 1 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Japanese/THE SAGACIOUS MONKEY AND THE BOAR.ann
# Primate ('Protagonist', 'Good') ('Protagonist', 'Neutral')
# Ungulate ('Protagonist', 'Evil') ('Default', 'Neutral')
# 1 0 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/TheCherokeeLegendOfTheFirstStrawberry.ann
# Plant ('Default', 'Good') ('Default', 'Neutral')
# Crop ('Protagonist', 'Good') ('Protagonist', 'Good')
# Shrub ('Protagonist', 'Neutral') ('Default', 'Good')
# 2 1 3
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/TheFirstFire.ann
# Corvidae ('Default', 'Neutral') ('Default', 'Good')
# Snake ('Default', 'Neutral') ('Default', 'Good')
# Owl ('Default', 'Neutral') ('Default', 'Good')
# Spider ('Protagonist', 'Good') ('Protagonist', 'Good')
# 4 1 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/TheLegendOfTheCherokeeRose.ann
# Plant ('Protagonist', 'Good') ('Protagonist', 'Good')
# 1 1 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/TheLegendOfTheFirstWoman.ann
# Plant ('Protagonist', 'Neutral') ('Protagonist', 'Good')
# Ungulate ('Default', 'Neutral') ('Neutral', 'Default')
# Crop ('Protagonist', 'Good') ('Protagonist', 'Good')
# Fowl ('Default', 'Neutral') ('Protagonist', 'Good')
# 2 1 4
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/TheSixthSunHasRisen.ann
# Testudine ('Default', 'Neutral') ('Default', 'Good')
# Primate ('Default', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/WhatBecameOfTheRabbit.ann
# Lagomorph ('Default', 'Neutral') ('Antagonist', 'Neutral')
# Ungulate ('Antagonist', 'Evil') ('Protagonist', 'Evil')
# 0 2 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/WhyTheDeersTeethAreBlunt.ann
# Ungulate ('Protagonist', 'Neutral') ('Antagonist', 'Neutral')
# Lagomorph ('Antagonist', 'Evil') ('Protagonist', 'Evil')
# 0 2 2
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/WhyTheMinkSmells.ann
# Mustelid ('Protagonist', 'Evil') ('Default', 'Neutral')
# 0 0 1
# /content/drive/Shareddrives/Folklore/Folklore and Fauna Project/data/Annotated/Folktales v2 Keer/Cherokee/WhyTheOwlHasASpottedCoat.ann
# Owl ('Protagonist', 'Neutral') ('Protagonist', 'Neutral')
# 1 1 1
# Role, Alignment, Total:  [53 47 97]
# Role kappa:  0.31958762886597936
# Alignment kappa:  0.22680412371134023
